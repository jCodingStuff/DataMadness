# %% [markdown]
# # Exploraaaaaaaaaaation #

# %%
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import seaborn as sns
import numpy as np

import json
from ast import literal_eval  # OP = OP, NP = P (by Articuno's Law)

# %matplotlib inline

# %%
datapath = 'data/'

# %% [markdown]
# ## Loading Recipes ##

# %%
filename = 'RAW_recipes.csv'

# %%
df_recipes = pd.read_csv(datapath + filename, index_col='id')

# %%
df_recipes['submitted'] = df_recipes['submitted'].astype('datetime64')

# %%
for col in ['nutrition', 'tags', 'ingredients', 'steps']:
    df_recipes[col] = df_recipes[col].apply(lambda x: literal_eval(x))

# %%
df_recipes = df_recipes[df_recipes['minutes'] < 300]

# %% [markdown]
# ## Loading Interactions ##

# %%
filename = 'RAW_interactions.csv'

# %%
df_inter = pd.read_csv(datapath + filename)

# %%
df_inter['date'] = df_inter['date'].astype('datetime64')

# %% [markdown]
# ## Potatoes ##

# %%
data = [[i, df_sub.shape[0], df_sub.rating.mean(), df_sub.rating.std()] for i, df_sub in df_inter.groupby('recipe_id')]
df_inter_recipe = pd.DataFrame(data, columns=['recipe_id', 'n_votes', 'avg_rating', 'std_rating'])

# %%
df_inter_recipe = df_inter_recipe.set_index('recipe_id')

# %%
df_inter_recipe
# Out:
#            n_votes  avg_rating  std_rating
# recipe_id
# 38               4    4.250000    0.500000
# 39               1    3.000000         NaN
# 40               9    4.333333    1.322876
# 41               2    4.500000    0.707107
# 43               1    1.000000         NaN
# ...            ...         ...         ...
# 537459           1    5.000000         NaN
# 537485           1    5.000000         NaN
# 537543           1    0.000000         NaN
# 537671           1    0.000000         NaN
# 537716           1    5.000000         NaN
#
# [231637 rows x 3 columns]

# %%
df = df_recipes.join(df_inter_recipe)

# %%
df
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 137739    arriba   baked winter squash mexican style       55           47892
# 31490               a bit different  breakfast pizza       30           26278
# 112140                     all in the kitchen  chili      130          196586
# 59389                             alouette  potatoes       45           68585
# 44061             amish  tomato ketchup  for canning      190           41706
# ...                                              ...      ...             ...
# 486161                                   zydeco soup       60          227978
# 493372                              zydeco spice mix        5         1500678
# 308080                     zydeco ya ya deviled eggs       40           37779
# 298512        cookies by design   cookies on a stick       29          506822
# 298509  cookies by design   sugar shortbread cookies       20          506822
#
#         submitted                                               tags  \
# id
# 137739 2005-09-16  [60-minutes-or-less, time-to-make, course, mai...
# 31490  2002-06-17  [30-minutes-or-less, time-to-make, course, mai...
# 112140 2005-02-25  [time-to-make, course, preparation, main-dish,...
# 59389  2003-04-14  [60-minutes-or-less, time-to-make, course, mai...
# 44061  2002-10-25  [weeknight, time-to-make, course, main-ingredi...
# ...           ...                                                ...
# 486161 2012-08-29  [ham, 60-minutes-or-less, time-to-make, course...
# 493372 2013-01-09  [15-minutes-or-less, time-to-make, course, pre...
# 308080 2008-06-07  [60-minutes-or-less, time-to-make, course, mai...
# 298512 2008-04-15  [30-minutes-or-less, time-to-make, course, pre...
# 298509 2008-04-15  [30-minutes-or-less, time-to-make, course, pre...
#
#                                           nutrition  n_steps  \
# id
# 137739        [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 31490     [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 112140   [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 59389     [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 44061     [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
# ...                                             ...      ...
# 486161  [415.2, 26.0, 34.0, 26.0, 44.0, 21.0, 15.0]        7
# 493372        [14.8, 0.0, 2.0, 58.0, 1.0, 0.0, 1.0]        1
# 308080         [59.2, 6.0, 2.0, 3.0, 6.0, 5.0, 0.0]        7
# 298512    [188.0, 11.0, 57.0, 11.0, 7.0, 21.0, 9.0]        9
# 298509     [174.9, 14.0, 33.0, 4.0, 4.0, 11.0, 6.0]        5
#
#                                                     steps  \
# id
# 137739  [make a choice and proceed with recipe, depend...
# 31490   [preheat oven to 425 degrees f, press dough in...
# 112140  [brown ground beef in large pot, add chopped o...
# 59389   [place potatoes in a large pot of lightly salt...
# 44061   [mix all ingredients& boil for 2 1 / 2 hours ,...
# ...                                                   ...
# 486161  [heat oil in a 4-quart dutch oven, add celery ...
# 493372          [mix all ingredients together thoroughly]
# 308080  [in a bowl , combine the mashed yolks and mayo...
# 298512  [place melted butter in a large mixing bowl an...
# 298509  [whip sugar and shortening in a large bowl , a...
#
#                                               description  \
# id
# 137739  autumn is my favorite time of year to cook! th...
# 31490   this recipe calls for the crust to be prebaked...
# 112140  this modified version of 'mom's' chili was a h...
# 59389   this is a super easy, great tasting, make ahea...
# 44061   my dh's amish mother raised him on this recipe...
# ...                                                   ...
# 486161  this is a delicious soup that i originally fou...
# 493372    this spice mix will make your taste buds dance!
# 308080                          deviled eggs, cajun-style
# 298512  i've heard of the 'cookies by design' company,...
# 298509  i've heard of the 'cookies by design' company,...
#
#                                               ingredients  n_ingredients  \
# id
# 137739  [winter squash, mexican seasoning, mixed spice...              7
# 31490   [prepared pizza crust, sausage patty, eggs, mi...              6
# 112140  [ground beef, yellow onions, diced tomatoes, t...             13
# 59389   [spreadable cheese with garlic and herbs, new ...             11
# 44061   [tomato juice, apple cider vinegar, sugar, sal...              8
# ...                                                   ...            ...
# 486161  [celery, onion, green sweet pepper, garlic clo...             22
# 493372  [paprika, salt, garlic powder, onion powder, d...             13
# 308080  [hard-cooked eggs, mayonnaise, dijon mustard, ...              8
# 298512  [butter, eagle brand condensed milk, light bro...             10
# 298509  [granulated sugar, shortening, eggs, flour, cr...              7
#
#         n_votes  avg_rating  std_rating
# id
# 137739        3         5.0    0.000000
# 31490         4         3.5    2.380476
# 112140        1         4.0         NaN
# 59389         2         4.5    0.707107
# 44061         1         5.0         NaN
# ...         ...         ...         ...
# 486161        6         5.0    0.000000
# 493372        1         5.0         NaN
# 308080        5         5.0    0.000000
# 298512        1         1.0         NaN
# 298509        3         2.0    2.645751
#
# [221458 rows x 14 columns]

# %%
df.describe()
# Out:
#              minutes  contributor_id        n_steps  n_ingredients  \
# count  221458.000000    2.214580e+05  221458.000000  221458.000000
# mean       48.939298    5.389693e+06       9.731990       9.027436
# std        45.966821    9.832466e+07       5.897762       3.711995
# min         0.000000    2.700000e+01       0.000000       1.000000
# 25%        20.000000    5.704200e+04       6.000000       6.000000
# 50%        35.000000    1.751240e+05       9.000000       9.000000
# 75%        60.000000    4.007080e+05      12.000000      11.000000
# max       295.000000    2.002290e+09     145.000000      43.000000
#
#              n_votes     avg_rating     std_rating
# count  221458.000000  221458.000000  133346.000000
# mean        4.849944       4.352174       0.790395
# std        17.178025       0.985539       0.880496
# min         1.000000       0.000000       0.000000
# 25%         1.000000       4.000000       0.000000
# 50%         2.000000       4.717949       0.577350
# 75%         4.000000       5.000000       1.258306
# max      1613.000000       5.000000       3.535534

# %%
sns.pairplot(df[['minutes', 'n_steps', 'n_ingredients', 'n_votes', 'avg_rating', 'std_rating']])

# %%
df['tags'].values[:2]
# Out:
# array([list(['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'side-dishes', 'vegetables', 'mexican', 'easy', 'fall', 'holiday-event', 'vegetarian', 'winter', 'dietary', 'christmas', 'seasonal', 'squash']),
#        list(['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'breakfast', 'main-dish', 'pork', 'american', 'oven', 'easy', 'kid-friendly', 'pizza', 'dietary', 'northeastern-united-states', 'meat', 'equipment'])],
#       dtype=object)
